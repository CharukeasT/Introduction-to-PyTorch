# %% [markdown]
# <a href="https://colab.research.google.com/github/CharukeasT/Introduction-to-PyTorch/blob/main/Intro_to_PyTorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
